# %%
import pandas as pd

# %%
df = pd.read_csv('happiness_train_abbr.csv')
df.head()
# Out:
#    id  happiness  survey_type  province  city  county      survey_time  \
# 0   1          4            1        12    32      59   2015/8/4 14:18
# 1   2          4            2        18    52      85  2015/7/21 15:04
# 2   3          4            2        29    83     126  2015/7/21 13:24
# 3   4          5            2        10    28      51  2015/7/25 17:33
# 4   5          4            1         7    18      36   2015/8/10 9:50
#
#    gender  birth  nationality  ...  family_income  family_m  family_status  \
# 0       1   1959            1  ...        60000.0         2              2
# 1       1   1992            1  ...        40000.0         3              4
# 2       2   1967            1  ...         8000.0         3              3
# 3       2   1943            1  ...        12000.0         3              3
# 4       2   1994            1  ...           -2.0         4              3
#
#    house  car  marital  status_peer  status_3_before  view  inc_ability
# ...

# %%
df.describe()
# Out:
#                id    happiness  survey_type     province         city  \
# count  8000.00000  8000.000000  8000.000000  8000.000000  8000.000000
# mean   4000.50000     3.850125     1.405500    15.155375    42.564750
# std    2309.54541     0.938228     0.491019     8.917100    27.187404
# min       1.00000    -8.000000     1.000000     1.000000     1.000000
# 25%    2000.75000     4.000000     1.000000     7.000000    18.000000
# 50%    4000.50000     4.000000     1.000000    15.000000    42.000000
# 75%    6000.25000     4.000000     2.000000    22.000000    65.000000
# max    8000.00000     5.000000     2.000000    31.000000    89.000000
#
#             county      gender        birth  nationality     religion  ...  \
# count  8000.000000  8000.00000  8000.000000   8000.00000  8000.000000  ...
# mean     70.619000     1.53000  1964.707625      1.37350     0.772250  ...
# std      38.747503     0.49913    16.842865      1.52882     1.071459  ...
# ...

# %%
df.dtypes
# Out:
# id                   int64
# happiness            int64
# survey_type          int64
# province             int64
# city                 int64
# county               int64
# survey_time         object
# gender               int64
# birth                int64
# nationality          int64
# religion             int64
# religion_freq        int64
# edu                  int64
# income               int64
# political            int64
# floor_area         float64
# height_cm            int64
# weight_jin           int64
# health               int64
# health_problem       int64
# depression           int64
# hukou                int64
# socialize            int64
# relax                int64
# learn                int64
# equity               int64
# class                int64
# work_exper           int64
# work_status        float64
# work_yr            float64
# work_type          float64
# work_manage        float64
# family_income      float64
# family_m             int64
# ...

# %%
df = df.drop(['id', 'survey_time'], axis=1)

# %%
df.head()
# Out:
#    happiness  survey_type  province  city  county  gender  birth  nationality  \
# 0          4            1        12    32      59       1   1959            1
# 1          4            2        18    52      85       1   1992            1
# 2          4            2        29    83     126       2   1967            1
# 3          5            2        10    28      51       2   1943            1
# 4          4            1         7    18      36       2   1994            1
#
#    religion  religion_freq  ...  family_income  family_m  family_status  \
# 0         1              1  ...        60000.0         2              2
# 1         1              1  ...        40000.0         3              4
# 2         0              3  ...         8000.0         3              3
# 3         1              1  ...        12000.0         3              3
# 4         1              1  ...           -2.0         4              3
#
# ...

# %%
df['age'] = 2015 - df['birth']

# %%
df.head()
# Out:
#    happiness  survey_type  province  city  county  gender  birth  nationality  \
# 0          4            1        12    32      59       1   1959            1
# 1          4            2        18    52      85       1   1992            1
# 2          4            2        29    83     126       2   1967            1
# 3          5            2        10    28      51       2   1943            1
# 4          4            1         7    18      36       2   1994            1
#
#    religion  religion_freq  ...  family_m  family_status  house  car  marital  \
# 0         1              1  ...         2              2      1    2        3
# 1         1              1  ...         3              4      1    2        1
# 2         0              3  ...         3              3      1    2        3
# 3         1              1  ...         3              3      1    1        7
# 4         1              1  ...         4              3      1    1        1
#
# ...

# %%
df.drop('birth', axis=1, inplace=True)

# %%
df.head()
# Out:
#    happiness  survey_type  province  city  county  gender  nationality  \
# 0          4            1        12    32      59       1            1
# 1          4            2        18    52      85       1            1
# 2          4            2        29    83     126       2            1
# 3          5            2        10    28      51       2            1
# 4          4            1         7    18      36       2            1
#
#    religion  religion_freq  edu  ...  family_m  family_status  house  car  \
# 0         1              1   11  ...         2              2      1    2
# 1         1              1   12  ...         3              4      1    2
# 2         0              3    4  ...         3              3      1    2
# 3         1              1    3  ...         3              3      1    1
# 4         1              1   12  ...         4              3      1    1
#
#    marital  status_peer  status_3_before  view  inc_ability  age
# ...

# %%
def change_multi_binary(x):
    if x >= 3:
        return 1

# %%
df['target'] =

# %%
df.to_csv('train.csv', index=False)
